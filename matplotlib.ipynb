# %% [markdown]
# # Matplotlib Practice

# %%
# !pip install matplotlib

# %% [markdown]
# ## Basic Line Chart
# Line charts are excellent for showing trends over time, making them ideal for displaying continuous data. They’re great for visualizing changes in data points, such as stock prices, temperature variations, or sales figures over a specific period.
#
# **When to use:** Use line charts when you want to showcase trends, patterns, or fluctuations in data over time.

# %%
from matplotlib import pyplot as plt
years = [1950,1960,1970,1980,1990,2000,2010]
gdp = [300.2,543.3,1075.9,2862.5,5979.6,10289.7,14958.3]

#creatre a line chart
#years on x-axis
#gdp on y-axis
plt.plot(years,gdp, color = 'green', marker ='o', linestyle = 'solid')
plt.title("Nominal GDP")

#add Label
plt.ylabel("Billions of $")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## More Complex Line Chart

# %%
variance = [1,2,4,8,16,32,64,128,256]
bias_squared = [256,128,64,32,16,8,4,2,1]
total_error = [x+y for x,y in zip(variance,bias_squared)]
xs = [i for i, _ in enumerate(variance)]

#Multiple Line Series
plt.plot(xs,variance,'g-',label='variance') # Green Solid Line
plt.plot(xs,bias_squared, 'r-.', label ='bias^2') # Red dot=dasheed line
plt.plot(xs,total_error, 'b:', label ='total_error') #blue dotted line

plt.legend(loc=9) # loc = 9 means "Top Center"
plt.xlabel("Model Complexity")
plt.xticks([])
plt.title("The Bias-Variance Trade-off")
plt.show()

# %% [markdown]
# ## Basic Bar Chart
# Bar charts are versatile and effective for comparing different categories of data. They present data as rectangular bars, with the length of each bar corresponding to the value it represents. Vertical bar charts are often used for category comparison, while horizontal bar charts work well for ranking items.
#
# **When to use:** Bar charts are suitable for **comparing data across different categories** or displaying **rankings**.

# %%
movies = ["Annie Hall", "Ben-Hur", "Casablanca", "Gandhi", "West Side Story"]
num_oscars = [5,11,3,8,10]

#plot bars with left x coordinates [0,1,2,3,4]
plt.bar(range(len(movies)),num_oscars)
plt.title("Oscar reward for each movies")
plt.ylabel("# of Academy Awards")

#label x-axis with movie name
plt.xticks(range(len(movies)),movies)
plt.show()

# %% [markdown]
# ### Distribution with Bar Chart

# %%
from collections import Counter
grades = [83,95,91,87,70,0,85,82,100,67,73,77,0]

#Bucket grades by decile, but put 100 in with the 90s
histogram = Counter(min(grade//10*10,90) for grade in grades)
plt.bar([x+5 for x in histogram.keys()], # Shift bars right by 5
        histogram.values(),              # Bar height
        10,                              # Give each bar a width of 10
        edgecolor = (0,0,0))
plt.axis([-5,105,0,5])                   # x-axis from -5 to 105
                                         # y-axis from 0 to 5

plt.xticks([10 * i for i in range(11)])  # x-axis labels at 0,10,...,100
plt.xlabel("Decile")
plt.ylabel("# of Students")
plt.title("Distribution of Exam 1 Grades")
plt.show()

# %% [markdown]
# ### Bad Example of Bar Chart

# %%
mentions = [500, 505]
years = [2017,2018]
plt.bar(years,mentions,0.8)
plt.xticks(years)
plt.ylabel("# of times I heard someone say 'data scioence' ")

# if you don't do this, matplotlib will label the x-axis 0, 1
plt.ticklabel_format(useOffset = False)

# misleading y-axis only shows the part above 500
plt.axis([2016.5,2018.5,499,506])
plt.title("Look at the Huge Increase!")
plt.show()

# %% [markdown]
# This chart is a bad example because y is not start from 0 that can make viewers missunderstanding

# %%
mentions = [500, 505]
years = [2017,2018]
plt.bar(years,mentions,0.8)
plt.xticks(years)
plt.ylabel("# of times I heard someone say 'data scioence' ")

# if you don't do this, matplotlib will label the x-axis 0, 1
plt.ticklabel_format(useOffset = False)

# misleading y-axis only shows the part above 500
plt.axis([2016.5,2018.5,0,550])
plt.title("Not so Huge Anymore")
plt.show()

# %% [markdown]
# It is bad because we cannot see the different

# %% [markdown]
# ## Scatter Plots
# Scatter plots are used to display the relationship between two variables. Each point represents an observation with values on both axes, making it easy to identify correlations, clusters, or outliers.
#
# **When to use:** Scatter plots are suitable for **showing relationships between two variables** and **identifying patterns** in data.

# %%
friends = [70,65,72,63,71,64,60,64,67]
minutes = [175,170,205,120,220,130,105,145,190]
labels = ['a','b','c','d','e','f','g','h','i']
plt.scatter(friends,minutes)

for label, friend_count, minute_count in zip(labels,friends,minutes):
    plt.annotate(label,
    xy = (friend_count,minute_count), # Put the label with its point
    xytext =(5,5),                    # but slightly offset
    textcoords ='offset points')

plt.title("Dialy Minute vs Number of Friends")
plt.xlabel("# of friends")
plt.ylabel("dialy minutes spent on the site")
plt.show()

# %% [markdown]
# ### Bad example of Scatter Plots

# %%
test_1_grades = [99,90,85,97,80]
test_2_grades = [100,85,60,90,70]

plt.scatter(test_1_grades,test_2_grades)
plt.title("Axes Aren't Comparable")
plt.xlabel("test 1 grade")
plt.ylabel("test 2 grade")
plt.show()

# %% [markdown]
# Because of we distribute a compared value, so the viewver may misunderstanding
#
# So, we can add `plt.axis("equal")` to make it more accurate

# %%
test_1_grades = [99,90,85,97,80]
test_2_grades = [100,85,60,90,70]

plt.scatter(test_1_grades,test_2_grades)
plt.title("Axes Are Comparable")
plt.axis("equal")
plt.xlabel("test 1 grade")
plt.ylabel("test 2 grade")
plt.show()

# %%
# !git init
# Out:
# Initialized empty Git repository in C:/Users/User/Desktop/Self/Basic Visualization with Python/.git/
